# %% [markdown]
#  <h2>Exploratory Data Analysis</h2>
#  Exploratory Data Analysis (EDA) is a method used to analyze and summarize datasets.
#  It contains information of all the passengers aboard the RMS Titanic, which unfortunately was shipwrecked. This dataset can be used to predict whether a given passenger survived or not.

# %%
import pandas as pd
titanic=pd.read_csv("train.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# View first five rows of the dataset
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#listing the columns
titanic.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Few conclusions
# Missing values in Age,Cabin,Embarked columns 
# few columns have inappropriate data types
# more than 70% values are missing in cabin columns will have to drop

# %%
#dropping cabin column 
titanic.drop(columns=['Cabin'],inplace=True)

# %%
# input missing values for age
# Strategy -mean
titanic['Age'].fillna(titanic['Age'].mean(),inplace=True)

# %%
titanic['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
titanic['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
# changing the Data Type
titanic[ 'Survived'] =titanic[ 'Survived' ].astype ( 'category') 
titanic ['Pclass'] =titanic[ 'Pclass' ].astype ('category')
titanic [' Sex' ]=titanic[ 'Sex' ].astype ('category') 
titanic[ 'Age' ] =titanic[ 'Age' ].astype('int')
titanic['Embarked']=titanic ['Embarked'].astype('category')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    category
#  11   Sex         891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(3)
# memory usage: 56.3+ KB

# %%
titanic.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
# let's start with survived column
import seaborn as sns
import matplotlib as plt
sns.countplot(x=titanic['Survived'])
death_percent=round ((titanic [ 'Survived' ].value_counts().values [0]/891)*100)
print("Out of 891 {} people died in the accident".format(death_percent))
# Out:
# Out of 891 62 people died in the accident

# %%
# Pclass column
print ((titanic["Pclass"].value_counts()/891)*100)
sns.countplot(titanic['Pclass'])
# Conclusion:Pclass was the most crowded class
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
print ((titanic["Sex"].value_counts()/891)*100)
sns.countplot(titanic['Sex'])
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
print(titanic["SibSp"].value_counts())
      
sns.countplot(x=titanic["SibSp"])
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
print((titanic['Parch'].value_counts()/891)*100)
sns.countplot(x=titanic['Parch'])
# Out:
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: Parch, dtype: float64
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
print((titanic['Embarked'].value_counts()/891)*100)
sns.countplot(x=titanic['Embarked'])
# Out:
# S    72.278339
# C    18.855219
# Q     8.641975
# Name: Embarked, dtype: float64
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
sns.boxplot(x=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
print("People with age in between 60 and 70 are", titanic[(titanic ['Age']>60) & (titanic['Age']<70)].shape[0])
print("People with age greater than 70 and 75 are",titanic[(titanic ['Age'] >=70) & (titanic['Age']<=75)].shape[0])
print("People with age greater than 75 are",titanic[titanic['Age']>75].shape[0])
print('-'*50)
print("People with age between 0and 1",titanic[titanic['Age']<1].shape[0])
# Out:
# People with age in between 60 and 70 are 15
# People with age greater than 70 and 75 are 6
# People with age greater than 75 are 1
# --------------------------------------------------
# People with age between 0and 1 7

# %%
sns.boxplot(x=titanic['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
print("People with fare in between $200 and $300",titanic[(titanic['Fare']>200) & (titanic['Fare']<300)].shape[0]) 
print("People with fare in greater than $300",titanic[titanic ['Fare']>300].shape[0])
# Out:
# People with fare in between $200 and $300 17
# People with fare in greater than $300 3

# %%
# Highly skewed data alot of people had cheaper tickets

# Survival with Pclass
sns.countplot(x=titanic['Survived'],hue=titanic['Pclass'])
pd.crosstab(titanic[ 'Pclass'], titanic[ 'Survived']).apply (lambda r: round ((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
# Survival with sex
sns.countplot(x=titanic['Survived'],hue=titanic['Sex'])
pd.crosstab(titanic['Sex'],titanic['Survived']).apply(lambda r: round ((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
#  Age vs Survived  
# violin Displays distribution of data
sns.violinplot(x ="Sex", y ="Age", hue ="Survived",
data = titanic, split = True)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
# Pclass  vs Survived  
group = titanic.groupby(['Pclass', 'Survived'])
pclass_survived = group.size().unstack()
sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
sns.pairplot(titanic)

# %%
titanic['Family_size']=titanic['Parch']+titanic['SibSp']

# %%
titanic.sample(5)
# Out:
#      PassengerId Survived Pclass  \
# 690          691        1      1
# 804          805        1      3
# 747          748        1      2
# 576          577        1      2
# 49            50        0      3
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 690                        Dick, Mr. Albert Adrian    male   31      1      0
# 804                        Hedman, Mr. Oskar Arvid    male   27      0      0
# 747                          Sinkkonen, Miss. Anna  female   30      0      0
# 576                           Garside, Miss. Ethel  female   34      0      0
# 49   Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female   18      1      0
#
#      Ticket    Fare Embarked     Sex  Family_size
# 690   17474  57.000        S    male            1
# 804  347089   6.975        S    male            0
# 747  250648  13.000        S  female            0
# 576  243880  13.000        S  female            0
# ...

# %%
# Building a Logistic Regression model
# Train Test Split
titanic.drop('Survived',axis=1).head()
# Out:
#    PassengerId Pclass                                               Name  \
# 0            1      3                            Braund, Mr. Owen Harris
# 1            2      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3      3                             Heikkinen, Miss. Laina
# 3            4      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5      3                           Allen, Mr. William Henry
#
#       Sex  Age  SibSp  Parch            Ticket     Fare Embarked     Sex  \
# 0    male   22      1      0         A/5 21171   7.2500        S    male
# 1  female   38      1      0          PC 17599  71.2833        C  female
# 2  female   26      0      0  STON/O2. 3101282   7.9250        S  female
# 3  female   35      1      0            113803  53.1000        S  female
# 4    male   35      0      0            373450   8.0500        S    male
#
#    Family_size
# 0            1
# 1            1
# 2            0
# 3            1
# ...

# %%
titanic['Survived'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: category
# Categories (2, int64): [0, 1]

# %% [markdown]
# # Conclusions :
# 1) Chance of female survival is higher than male survival
#
# 2) travelling  in pclass 3 was deadlist
#
# 3) somehow people going to c survived more
#
# 4) people in the age range of 20 to 40 had a higher chance of not surviving
